# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sweetviz as sv
working_dir = os.getcwd()
file_dir = os.path.join(working_dir , "Data")
dataset = os.path.join(file_dir , "car_evaluation.csv")

# %%
data = pd.read_csv(dataset , header=None)
data.head()
# Out:
#        0      1  2  3      4     5      6
# 0  vhigh  vhigh  2  2  small   low  unacc
# 1  vhigh  vhigh  2  2  small   med  unacc
# 2  vhigh  vhigh  2  2  small  high  unacc
# 3  vhigh  vhigh  2  2    med   low  unacc
# 4  vhigh  vhigh  2  2    med   med  unacc

# %%
data.columns = ['Price' , 'Maintenance Cost' , 'Number of Doors' , 'Capacity' , 'Size of Luggage Boot' , "Safety" , "Decision"]
data.head()
# Out:
#    Price Maintenance Cost Number of Doors Capacity Size of Luggage Boot  \
# 0  vhigh            vhigh               2        2                small
# 1  vhigh            vhigh               2        2                small
# 2  vhigh            vhigh               2        2                small
# 3  vhigh            vhigh               2        2                  med
# 4  vhigh            vhigh               2        2                  med
#
#   Safety Decision
# 0    low    unacc
# 1    med    unacc
# 2   high    unacc
# 3    low    unacc
# 4    med    unacc

# %%
price = pd.crosstab(data['Price'] , data['Decision'])
price.head()
# Out:
# Decision  acc  good  unacc  vgood
# Price
# high      108     0    324      0
# low        89    46    258     39
# med       115    23    268     26
# vhigh      72     0    360      0

# %%
price.plot(kind =  'bar'  , figsize = (10,7))
plt.title("bar graph")
plt.xlabel("price ->")
plt.ylabel("count ^")
plt.legend()
plt.show()

# %%
maintenance = pd.crosstab(data['Maintenance Cost'] , data['Decision'])
maintenance.plot(kind = 'bar' , figsize = (10,7))
plt.xlabel("maintenance price ->")
plt.ylabel("count ->")
plt.legend()
plt.show()

# %%
maintenance = pd.crosstab(data['Safety'] , data['Decision'])
maintenance.plot(kind = 'bar' , figsize = (10,7))
plt.xlabel("safety ->")
plt.ylabel("count ->")
plt.legend()
plt.show()

# %%
maintenance = pd.crosstab(data['Number of Doors'] , data['Decision'])
maintenance.plot(kind = 'bar' , figsize = (10,7))
plt.xlabel("no of doors ->")
plt.ylabel("count ->")
plt.legend()
plt.show()

# %%
maintenance = pd.crosstab(data['Capacity'] , data['Decision'])
maintenance.plot(kind = 'bar' , figsize = (10,7))
plt.xlabel("Capacity ->")
plt.ylabel("count ->")
plt.legend()
plt.show()

# %%
maintenance = pd.crosstab(data['Size of Luggage Boot'] , data['Decision'])
maintenance.plot(kind = 'bar' , figsize = (10,7))
plt.xlabel("Size of Luggage Boot ->")
plt.ylabel("count ->")
plt.legend()
plt.show()

# %%
data.Decision.replace(('unacc' , 'acc' , 'good' , 'vgood') , (0,1,2,3) , inplace=True)
data['Decision'].value_counts()
# Out:
# 0    1210
# 1     384
# 2      69
# 3      65
# Name: Decision, dtype: int64

# %%
data['Size of Luggage Boot'].replace(('small' , 'med','big') , (0,1,2) , inplace=True)
data['Size of Luggage Boot'].value_counts()
# Out:
# 2    576
# 1    576
# 0    576
# Name: Size of Luggage Boot, dtype: int64

# %%
data['Safety'].replace(('low' , 'med','high') , (0,1,2) , inplace=True)
data['Safety'].value_counts()
# Out:
# 2    576
# 1    576
# 0    576
# Name: Safety, dtype: int64

# %%
data['Price'].replace(('low' , 'med','high','vhigh') , (0,1,2,3) , inplace=True)
data['Price'].value_counts()
# Out:
# 3    432
# 2    432
# 1    432
# 0    432
# Name: Price, dtype: int64

# %%
data['Maintenance Cost'].replace(('low' , 'med','high','vhigh') , (0,1,2,3) , inplace=True)
data['Maintenance Cost'].value_counts()
# Out:
# 3    432
# 2    432
# 1    432
# 0    432
# Name: Maintenance Cost, dtype: int64

# %%
data['Number of Doors'].replace('5more', 5, inplace = True)
data['Number of Doors'].value_counts()
# Out:
# 4    432
# 2    432
# 3    432
# 5    432
# Name: Number of Doors, dtype: int64

# %%
data['Capacity'].replace('more', 5, inplace = True)
data['Capacity'].value_counts()
# Out:
# 4    576
# 2    576
# 5    576
# Name: Capacity, dtype: int64

# %%
data.head()
# Out:
#    Price  Maintenance Cost Number of Doors Capacity  Size of Luggage Boot  \
# 0      3                 3               2        2                     0
# 1      3                 3               2        2                     0
# 2      3                 3               2        2                     0
# 3      3                 3               2        2                     1
# 4      3                 3               2        2                     1
#
#    Safety  Decision
# 0       0         0
# 1       1         0
# 2       2         0
# 3       0         0
# 4       1         0

# %%
x = data.iloc[: , :6]
y = data.iloc[: , 6]

# %%
data.Decision.replace((0,1,2,3) , (0,1,1,1) , inplace = True)
data['Decision'].value_counts()
# Out:
# 0    1210
# 1     518
# Name: Decision, dtype: int64

# %%
y.value_counts()
# Out:
# 0    1210
# 1     518
# Name: Decision, dtype: int64

# %%
from sklearn.model_selection import train_test_split

x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.15,random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

model = DecisionTreeClassifier(max_depth = 6)
model.fit(x_train , y_train)

y_pred = model.predict(x_test)

print("Training Accuracy" , model.score(x_train , y_train))
print("Training Accuracy" , model.score(x_test , y_test))
# Out:
# Training Accuracy 0.9673024523160763
# Training Accuracy 0.9692307692307692

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100)
model.fit(x_train , y_train)

y_pred = model.predict(x_test)

print("Training Accuracy" , model.score(x_train , y_train))
print("Training Accuracy" , model.score(x_test , y_test))
# Out:
# Training Accuracy 1.0
# Training Accuracy 0.9923076923076923

# %%
imp = model.feature_importances_

print(imp)
# Out:
# [0.12120711 0.10428678 0.04086817 0.32201895 0.06832069 0.3432983 ]

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors = 5)
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("Training Accuracy" , model.score(x_train , y_train))
print("Training Accuracy" , model.score(x_test , y_test))
# Out:
# Training Accuracy 0.9918256130790191
# Training Accuracy 0.9730769230769231
